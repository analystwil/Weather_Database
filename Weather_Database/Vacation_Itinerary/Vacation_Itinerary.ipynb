# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import gmaps.datasets


# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("/Users/Ash/Desktop/BOOTCAMP/Class/Weather_Database/Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 0        1       Cartagena      CO     78.80       broken clouds  10.3997
# 1        9  Saint-Philippe      RE     77.00     overcast clouds -21.3585
# 2       20           Vaini      TO     86.00          light rain -21.2000
# 3       28         Kavieng      PG     84.45          light rain  -2.5744
# 4       32           Kapaa      US     78.80       broken clouds  22.0752
#
#         Lng                              Hotel Name
# 0  -75.5144         Hotel Colombia Real - Cartagena
# 1   55.7679            Chambres d'hôte "La Trinité"
# 2 -175.2000                     Keleti Beach Resort
# 3  150.7967                     Nusa Island Retreat
# 4 -159.3190  Sheraton Kauai Resort at Coconut Beach

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]
hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Colombia Real - Cartagena</dd>\n<dt>City</dt><dd>Cartagena</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Current Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Chambres d\'hôte "La Trinité"</dd>\n<dt>City</dt><dd>Saint-Philippe</dd>\n<dt>Country</dt><dd>RE</dd>\n<dt>Current Description</dt><dd>overcast clouds</dd>\n<dt>Max Temp</dt><dd>77.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Keleti Beach Resort</dd>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Current Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>86.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nusa Island Retreat</dd>\n<dt>City</dt><dd>Kavieng</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Current Description</dt><dd>light rain</dd>\n<dt>Max Temp</dt><dd>84.45 °F</dd>\n</dl>\n',
# ...

# %%
# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]
locations
# Out:
#          Lat       Lng
# 0    10.3997  -75.5144
# 1   -21.3585   55.7679
# 2   -21.2000 -175.2000
# 3    -2.5744  150.7967
# 4    22.0752 -159.3190
# ..       ...       ...
# 465   8.1222  -63.5497
# 466 -20.5167   57.5167
# 467  -8.1450  159.5921
# 468  -5.7950  -35.2094
# 469 -24.8667  113.6333
#
# [470 rows x 2 columns]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# %%
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df["City"] == "Coruripe") & (vacation_df["Country"] == "BR")]
vacation_end = vacation_df.loc[(vacation_df["City"] == "Coruripe") & (vacation_df["Country"] == "BR")]
vacation_stop1 = vacation_df.loc[(vacation_df["City"] == "Pitimbu") & (vacation_df["Country"] == "BR")]
vacation_stop2 = vacation_df.loc[(vacation_df["City"] == "Natal") & (vacation_df["Country"] == "BR")]
vacation_stop3 = vacation_df.loc[(vacation_df["City"] == "Maragogi") & (vacation_df["Country"] == "BR")]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = (vacation_start["Lat"].to_numpy()[0], vacation_start ["Lng"].to_numpy()[0])
start
# Out:
# (-10.1256, -36.1756)

# %%
end = (vacation_end["Lat"].to_numpy()[0], vacation_end ["Lng"].to_numpy()[0])
end
# Out:
# (-10.1256, -36.1756)

# %%
stop1 = (vacation_stop1["Lat"].to_numpy()[0], vacation_stop1 ["Lng"].to_numpy()[0])
stop1
# Out:
# (-7.4706, -34.8086)

# %%
stop2 = (vacation_stop2["Lat"].to_numpy()[0], vacation_stop2 ["Lng"].to_numpy()[0])
stop2
# Out:
# (-5.795, -35.2094)

# %%
stop3 = (vacation_stop3["Lat"].to_numpy()[0], vacation_stop3 ["Lng"].to_numpy()[0])
stop3
# Out:
# (-9.0122, -35.2225)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

# Latitude-longitude pairs
start = (-10.1256, -36.1756)
end = (-10.1256, -36.1756)
stop1 = (-7.4706, -34.8086)
stop2 = (-5.795, -35.2094)
stop3 = (-9.0122, -35.2225)

#fig = gmaps.figure()
#start2stop3 = gmaps.directions_layer(start, stop3)
#fig.add_layer(start2stop3)
#fig

start2stop3_via_brazil = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(start2stop3_via_brazil)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_end,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID      City Country  Max Temp Current Description      Lat      Lng  \
# 0     1444  Coruripe      BR     78.69       broken clouds -10.1256 -36.1756
# 1     1444  Coruripe      BR     78.69       broken clouds -10.1256 -36.1756
# 2     1566   Pitimbu      BR     78.80          few clouds  -7.4706 -34.8086
# 3     1839     Natal      BR     80.60    scattered clouds  -5.7950 -35.2094
# 4      707  Maragogi      BR     78.42           clear sky  -9.0122 -35.2225
#
#                                  Hotel Name
# 0               Pousada e Hotel Litoral Sul
# 1               Pousada e Hotel Litoral Sul
# 2                          Reserva do Abiaí
# 3                  Villa Park Hotel | Natal
# 4  Salinas do Maragogi All Inclusive Resort

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]
hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Pousada e Hotel Litoral Sul</dd>\n<dt>City</dt><dd>Coruripe</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada e Hotel Litoral Sul</dd>\n<dt>City</dt><dd>Coruripe</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Description</dt><dd>broken clouds</dd>\n<dt>Max Temp</dt><dd>78.69 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Reserva do Abiaí</dd>\n<dt>City</dt><dd>Pitimbu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Description</dt><dd>few clouds</dd>\n<dt>Max Temp</dt><dd>78.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Park Hotel | Natal</dd>\n<dt>City</dt><dd>Natal</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Description</dt><dd>scattered clouds</dd>\n<dt>Max Temp</dt><dd>80.6 °F</dd>\n</dl>\n',
# ...

# %%
# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]
locations
# Out:
#        Lat      Lng
# 0 -10.1256 -36.1756
# 1 -10.1256 -36.1756
# 2  -7.4706 -34.8086
# 3  -5.7950 -35.2094
# 4  -9.0122 -35.2225

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# %%
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
